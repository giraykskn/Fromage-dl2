# %%
import numpy as np
import matplotlib.pyplot as plt 

results = np.load("results/EX1_R1_C1_part1.npz")
#results.files

#print(results)
# [100, 1, 256, 256, 3]
imgs = results["images"][1][0]
plt.imshow(imgs)
#results["story_ids"]

#story_ids = results["story_ids"][2][0]
#plt.imshow(story_ids)
